# %%
# now this is my 2nd AI model
# its a medical chatbot jupyter notebook

# %%
#testing ollama connectivity
import ollama
response= ollama.chat(
        model='tinyllama',
        messages=[
            {
                'role':'user',
                'content':'what is the oncology '
            }
        ]

)
print(response['message']['content'])
# Out:
# Oncology, derived from the Greek words "o-kanion" (meaning "cancer") and "logia" (meaning "study"), is a branch of medicine that deals with the diagnosis, prevention, prognosis, and treatment of cancer. It involves the study of tumors and their growth, as well as the development of new treatments for cancer. Oncology also covers the evaluation of patients with cancer and the selection of appropriate therapies based on their individual medical history and clinical characteristics. The goal of oncology is to provide the best possible care for cancer patients by developing evidence-based treatment plans, conducting clinical trials, and coordinating care across multiple healthcare professionals.

# %%
#testing user input in notebook
import ollama
user_input=input("ask question...")
response= ollama.chat(
    model='tinyllama',
    messages=[
        {
            'role':'user',
            'content':user_input
        }
    ]
)
print(response['message']['content'])
# Out:
# The Whipple procedure, also known as the Marfan Syndrome Procedure, is a surgical technique used to treat patients with Marfan syndrome. It involves removing a small part of the heart or blood vessel (the atrial appendage) that is abnormally large and weakened due to Marfan syndrome.
#
# The procedure is performed under general anesthesia or local sedation, and takes about 30 minutes to complete. During the surgery, the surgeon makes a small incision in the patient's chest cavity and removes the atrial appendage through that incision. The entire procedure is monitored by an experienced cardiothoracic surgeon who can perform minimally invasive techniques in case of complications.
#
# The purpose of the Whipple procedure is to reduce the risk of atrial fibrillation (an irregular heartbeat) and prevent the buildup of blood in the atria, which can lead to heart failure in patients with Marfan syndrome. The surgery has been approved by the FDA for use in patients aged 10 years or older.
#
# The Whipple procedure is one of several options available for treating Marfan Syndrome and can be used in combination with other treatments, such as chemotherapy or surgical correction of congenital heart defects. In some cases, the Whipple procedure may not be necessary and patients may be treated with less invasive techniques or alternative therapies.

# %%
#defining modular fxn
def ask_ai(question):
    response= ollama.chat(
        model='tinyllama',
        messages=[
            {
                'role':'user',
                'content':question
            }
        ]

    )
    return response['message']['content']

# %%
def medicalassistance_bot(question):
    response= ollama.chat(
        model='tinyllama',
        messages=[
            {
                'role':'user',
                'content':""""you are a medical assistance bot:
                rules:
                -greate the user with a precise beautiful context
                -be polite and friendly
                -give a accurate analysis of the disease or report but precise
                -check the blood pressure and pulse rate if asked
                -suggest the general medication by seeing the symptoms of patient
                -suggest the test and do and don't"""
            },
            {
                'role':'user',
                'content':question
            }            
        ]
    )
    return response['message']['content']

# %%
print(medicalassistance_bot("iam havinga high fever of 102.45 suggest me what to do and also give me medication"))
# Out:
# Medication:
#
# If you are having a high fever, please listen carefully to the symptoms mentioned above. If you suspect that you have COVID-19, you should take precautions and consult your healthcare provider immediately. Here are some tips for taking medication safely and effectively:
#
# 1. Consult with your healthcare provider before taking any medications. They will advise on the best course of treatment for your specific symptoms and condition. 2. Check with your pharmacist or a trusted online resource about the recommended dosage and dosing schedule for your prescription medication. 3. Only use the medication as directed by your healthcare provider, especially if you are taking other drugs for chronic conditions. 4. If you experience side effects while taking medications, consult with your healthcare provider. They can provide further advice on how to manage these symptoms or adjust your treatment plan accordingly. I hope this helps! If you have any questions or concerns regarding your medication, don't hesitate to reach out to your healthcare provider or the pharmacist.
